# %% [markdown]
# # Exploratory data analysis in Python

# %% [markdown]
# ## Importing the required libraries for EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the data into the data frame.

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# To display the top 5 rows 
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# To display the botton 5 rows
df.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ## Checking the types of data

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ## Dropping irrelevant columns

# %%
df = df.drop(columns=['Engine Fuel Type', 'Number of Doors'])

# %%
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# ## Renaming the columns

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders"})

# %%
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0         Coupe           26        19        3916  46135
# ...

# %% [markdown]
# ## Dropping the duplicate rows

# %%
df.shape
# Out:
# (11914, 14)

# %%
df[df.duplicated()]
# Out:
#          Make     Model  Year     HP  Cylinders Transmission Type  \
# 14        BMW  1 Series  2013  230.0        6.0            MANUAL
# 18       Audi       100  1992  172.0        6.0            MANUAL
# 20       Audi       100  1992  172.0        6.0            MANUAL
# 24       Audi       100  1993  172.0        6.0            MANUAL
# 25       Audi       100  1993  172.0        6.0            MANUAL
# ...       ...       ...   ...    ...        ...               ...
# 11481  Suzuki      X-90  1998   95.0        4.0            MANUAL
# 11603   Volvo      XC60  2017  302.0        4.0         AUTOMATIC
# 11604   Volvo      XC60  2017  240.0        4.0         AUTOMATIC
# 11708  Suzuki       XL7  2008  252.0        6.0         AUTOMATIC
# 11717  Suzuki       XL7  2008  252.0        6.0         AUTOMATIC
#
#            Driven_Wheels               Market Category Vehicle Size  \
# 14      rear wheel drive            Luxury,Performance      Compact
# ...

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# HP                   11845
# Cylinders            11884
# Transmission Type    11914
# Driven_Wheels        11914
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0         Coupe           26        19        3916  46135
# ...

# %%
df.count()
# Out:
# Make                 11198
# Model                11198
# Year                 11198
# HP                   11129
# Cylinders            11168
# Transmission Type    11198
# Driven_Wheels        11198
# Market Category       7823
# Vehicle Size         11198
# Vehicle Style        11198
# highway MPG          11198
# city mpg             11198
# Popularity           11198
# MSRP                 11198
# dtype: int64

# %%
df.shape
# Out:
# (11198, 14)

# %% [markdown]
# ## Dropping the missing or null values

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# HP                     69
# Cylinders              30
# Transmission Type       0
# Driven_Wheels           0
# Market Category      3375
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df = df.dropna()  # Dropping the missing values

# %%
df.count()
# Out:
# Make                 7736
# Model                7736
# Year                 7736
# HP                   7736
# Cylinders            7736
# Transmission Type    7736
# Driven_Wheels        7736
# Market Category      7736
# Vehicle Size         7736
# Vehicle Style        7736
# highway MPG          7736
# city mpg             7736
# Popularity           7736
# MSRP                 7736
# dtype: int64

# %%
df.shape
# Out:
# (7736, 14)

# %% [markdown]
# ## Detecting Outliers

# %%
sns.boxplot(x=df['MSRP'])
# Out:
# <Axes: xlabel='MSRP'>

# %%
sns.boxplot(x=df['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df['Cylinders'])
# Out:
# <Axes: xlabel='Cylinders'>

# %% [markdown]
# ## Plot different features against one another (scatter), against frequency (histogram)

# %%
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0         Coupe           26        19        3916  46135
# ...

# %% [markdown]
# ## Histogram

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0         Coupe           26        19        3916  46135
# ...

# %%
df = df.rename(columns={'MSRP':'Price'})

# %%
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1  BMW    1 Series  2011  300.0        6.0            MANUAL
# 2  BMW    1 Series  2011  300.0        6.0            MANUAL
# 3  BMW    1 Series  2011  230.0        6.0            MANUAL
# 4  BMW    1 Series  2011  230.0        6.0            MANUAL
#
#       Driven_Wheels                        Market Category Vehicle Size  \
# 0  rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1  rear wheel drive                     Luxury,Performance      Compact
# 2  rear wheel drive                Luxury,High-Performance      Compact
# 3  rear wheel drive                     Luxury,Performance      Compact
# 4  rear wheel drive                                 Luxury      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity  Price
# 0         Coupe           26        19        3916  46135
# ...

# %%
df2 = pd.read_csv('train.csv')

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Age

# %%
df2['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df2['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df2['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df2['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df2[df2['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df2['Age'].isnull().sum()/len(df2['Age'])
# Out:
# 0.19865319865319866

# %% [markdown]
# ## Fare

# %%
df2['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df2['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df2['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df2['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df2[df2['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df2['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Univariate Analysis on Categorical columns

# %%
df2['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df2['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df2['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df2['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Understand type of relationship
# ### Numerical - Numerical
# ### a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots
# ### b. Check correlation coefficent to check linear relationship
# ### Numerical - Categorical - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
# ### a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots
# ### Categorical - Categorical
# ### a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
# ### b. You can plots like heatmap, stacked barplots, treemaps

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(pd.crosstab(df2['Survived'],df2['Pclass'],normalize='columns') * 100, annot=True)
# Percentage of people survived in each class
# Purpose of heatmap is to show the relationship beteween two categorical variables
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df2['Survived'],df2['Sex'],normalize='columns')*100
# crosstab is used to show the relationship between two categorical variables, here we are showing the percentage of people survived based on their gender.
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df2['Survived'],df2['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df2['Pclass'],df2['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# survived and age

df2[df2['Survived'] == 1]['Age'].plot(kind='kde',label='Survived') # kde is used to plot the density plot. Desnity plot is used to show the distribution of a variable
df2[df2['Survived'] == 0]['Age'].plot(kind='kde',label='Not Survived')

plt.legend()
plt.show()

# %%
df2[df2['Pclass'] == 1]['Age'].mean()
# Out:
# 38.233440860215055

# %%
df2['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df2[df2['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df2[df2['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...
